# %%
password=input("Enter password:")
if password== "adin123":
    print("Access Granted")
else:
    print("Access Denied")
# Out:
# Enter password: 123
# Access Denied

# %%
age =int(input("Enter your age:"))
if age < 13:
    print("child")
elif 13 <= age <= 19:
    print("Teen")
elif 20 <= age <= 59:
    print("Adult")
else:
    print("Senior")
# Out:
# Enter your age: 100
# Senior

# %%
num = int(input("Enter a number:"))
if num > 0:
    print("Positive")
else:
    print("Not positive")
if 10 <= num <=50:
    print("The number is between 10 and ")
